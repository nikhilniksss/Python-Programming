# %%
# import libraries

import pandas as pd

# %%
# create a table manually

data = {
    "name":["nick","Rahul","Ankit"],
    "Age": [30,32,34],
    "salary":[1000,5000,10000]
}

df = pd.DataFrame(data)
df
# Out:
#     name  Age  salary
# 0   nick   30    1000
# 1  Rahul   32    5000
# 2  Ankit   34   10000

# %%
# reading csv and create dataframe

df = pd.read_csv("/Users/nikhilsingh/Desktop/Python-Programming/pandas datasets/orders.csv")
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
# Top 10 rows

df.head(10)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %%
# bottom 10 rows

df.tail(10)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 40  Central  TEC-PH-10000486       Technology  371.2         4    41.8
# ...

# %%
# check datatype of every column

df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
# info about dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %%
# statistics of the dataframe columns

df.describe()
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %%
# check columns

df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %%
# changing the sequence of the column in dataframe and also rename

df.columns = ['order_date','order_id', 'ship_date', 'ship_mode', 'cust_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

df.head()
# Out:
#        order_date    order_id   ship_date       ship_mode   cust_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class  CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class  CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class  DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class  SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class  SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
# when dataset has no header

df = pd.read_csv("/Users/nikhilsingh/Desktop/Python-Programming/pandas datasets/orders.csv",header=None)
df.head()
# Out:
#                0           1           2               3            4   \
# 0        order_id  order_date   ship_date       ship_mode  customer_id
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
#
#        5                6                7      8         9       10
# 0  region       product_id         category  sales  quantity  profit
# 1   South  FUR-BO-10001798        Furniture    262         2    41.9
# 2   South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 3    West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 4   South  FUR-TA-10000577        Furniture  957.6         5    -383

# %%
# another rename method

df.rename(columns={"order_id":"OID"},inplace=True)
df.head()
# Out:
#               OID  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
# selecting columns

df = df[['order_id', 'order_date', 'ship_date', 'ship_mode']]
df.head(3)
# Out:
#          order_id  order_date   ship_date     ship_mode
# 0  CA-2020-152156  08-11-2020  11-11-2020  Second Class
# 1  CA-2020-152156  08-11-2020  11-11-2020  Second Class
# 2  CA-2020-138688  12-06-2020  16-06-2020  Second Class

# %%
# select single column

df['order_id']
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %%
# check the type

print(type(data))
print(type(df))
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# use of iloc, it gives index location

df.iloc[0:5]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
# give me till 3
df.iloc[:4]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0

# %%
# give me after 45 till end of the df

df.iloc[45:]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 45  Central  OFF-BI-10003291  Office Supplies   17.5         2     8.2
# 46  Central  OFF-ST-10001713  Office Supplies  212.0         4     8.5
# 47     East  TEC-AC-10002167       Technology   45.0         3     5.0
# 48     East  TEC-PH-10003988       Technology   21.8         2     6.1
# 49  Central  OFF-BI-10004410  Office Supplies   38.2         6    18.0

# %%
# multiple selection

df.iloc[[2,4,6,8,10]]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#          product_id         category   sales  quantity  profit
# 2   OFF-LA-10000240  Office Supplies    14.6         2     6.9
# 4   OFF-ST-10000760  Office Supplies    22.4         2     2.5
# 6   OFF-AR-10002833  Office Supplies     7.3         4     2.0
# 8   OFF-BI-10003910  Office Supplies    18.5         3     5.8
# 10  FUR-TA-10001539        Furniture  1706.2         9    85.3

# %%
# loc

df.loc[0:10,['order_id','order_date','ship_date']]
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018

# %%
# make order id an index 

df.set_index('order_id').head()
# Out:
#                 order_date   ship_date       ship_mode customer_id region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#                      product_id         category  sales  quantity  profit
# order_id
# CA-2020-152156  FUR-BO-10001798        Furniture  262.0         2    41.9
# CA-2020-152156  FUR-CH-10000454        Furniture  731.9         3   219.6
# CA-2020-138688  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# US-2019-108966  FUR-TA-10000577        Furniture  957.6         5  -383.0
# US-2019-108966  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
# make this effective using inplace

df.set_index('order_id',inplace=True)
df.head()
# Out:
#                 order_date   ship_date       ship_mode customer_id region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#                      product_id         category  sales  quantity  profit
# order_id
# CA-2020-152156  FUR-BO-10001798        Furniture  262.0         2    41.9
# CA-2020-152156  FUR-CH-10000454        Furniture  731.9         3   219.6
# CA-2020-138688  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# US-2019-108966  FUR-TA-10000577        Furniture  957.6         5  -383.0
# US-2019-108966  OFF-ST-10000760  Office Supplies   22.4         2     2.5
