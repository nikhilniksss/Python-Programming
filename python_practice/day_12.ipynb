# %% [markdown]
# ### Pandas tutorial

# %%
import pandas as pd

# %%
emp = {'name':['Nikhil','Amit','Rahul'],
        'gender':['Male','Male','Male'],
        'email':['nikhil@gmail.com','amit@yahoo.com','rahul@reddif.mail']}

# %%
# creating a dataframe

df_emp = pd.DataFrame(emp)

# %%
df_emp
# Out:
#      name gender              email
# 0  Nikhil   Male   nikhil@gmail.com
# 1    Amit   Male     amit@yahoo.com
# 2   Rahul   Male  rahul@reddif.mail

# %%
# accessing name

df_emp['name']
# Out:
# 0    Nikhil
# 1      Amit
# 2     Rahul
# Name: name, dtype: object

# %%
df_emp.name
# Out:
# 0    Nikhil
# 1      Amit
# 2     Rahul
# Name: name, dtype: object

# %%
# info of df

df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   gender  3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
# describe

df_emp.describe()
# Out:
#           name gender             email
# count        3      3                 3
# unique       3      1                 3
# top     Nikhil   Male  nikhil@gmail.com
# freq         1      3                 1

# %%
type(df_emp['name'])
# Out:
# pandas.core.series.Series

# %%
# reading from files

df = pd.read_csv(r'/Users/nick_mac/Desktop/python/namastepython/orders.txt')

# %%
df.head()
# Out:
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3  Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4  Office Supplies  OFF-FA-10000611    2.368    0.8288

# %%
# top 10 rows

df.head(10)
# Out:
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
# 5  CA-2018-100391  2018-05-25     Barry Weirich  New York City
# 6  CA-2018-100678  2018-04-18      Kunst Miller        Houston
# 7  CA-2018-100706  2018-12-16   Laurel Elliston    Springfield
# 8  CA-2018-100762  2018-11-24        Nat Gilpin        Jackson
# 9  CA-2018-100860  2018-03-26     Cindy Stewart         Pomona
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# ...

# %%
# bottom 10

df.tail(10)
# Out:
#             order_id  order_date      customer_name           city  \
# 4999  US-2021-167570  2021-12-08        Emily Grady   Philadelphia
# 5000  US-2021-167920  2021-12-09           John Lee       Richmond
# 5001  US-2021-168116  2021-11-04     Grant Thornton     Burlington
# 5002  US-2021-168613  2021-10-08        Gary McGarr  New York City
# 5003  US-2021-168690  2021-01-07      Thais Sissman   Ormond Beach
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales   profit
# 4999        Furniture  FUR-CH-10003396  215.544 -58.5048
# 5000  Office Supplies  OFF-AP-10000159  214.900  62.3210
# 5001  Office Supplies  OFF-AP-10002457  167.440  14.6510
# ...

# %%
# access single column

df['order_id']
# Out:
# 0       CA-2018-100006
# 1       CA-2018-100090
# 2       CA-2018-100293
# 3       CA-2018-100328
# 4       CA-2018-100363
#              ...
# 5004    US-2021-168802
# 5005    US-2021-169320
# 5006    US-2021-169488
# 5007    US-2021-169502
# 5008    US-2021-169551
# Name: order_id, Length: 5009, dtype: object

# %%
# access multiple columns

df[['order_id','order_date','category']]
# Out:
#             order_id  order_date         category
# 0     CA-2018-100006  2018-09-07       Technology
# 1     CA-2018-100090  2018-07-08        Furniture
# 2     CA-2018-100293  2018-03-14  Office Supplies
# 3     CA-2018-100328  2018-01-28  Office Supplies
# 4     CA-2018-100363  2018-04-08  Office Supplies
# ...              ...         ...              ...
# 5004  US-2021-168802  2021-11-03  Office Supplies
# 5005  US-2021-169320  2021-07-23  Office Supplies
# 5006  US-2021-169488  2021-09-07  Office Supplies
# 5007  US-2021-169502  2021-08-28  Office Supplies
# 5008  US-2021-169551  2021-07-07        Furniture
#
# [5009 rows x 3 columns]

# %%
# select row 1 using iloc which is called index loc

df.iloc[1]
# Out:
# order_id          CA-2018-100090
# order_date            2018-07-08
# customer_name         Ed Braxton
# city               San Francisco
# category               Furniture
# product_id       FUR-TA-10003715
# sales                    502.488
# profit                  -87.9354
# Name: 1, dtype: object

# %%
# row and column

df.iloc[0,2]
# Out:
# 'Dennis Kane'

# %%
# loc is labeled based

df.loc[1]
# Out:
# order_id          CA-2018-100090
# order_date            2018-07-08
# customer_name         Ed Braxton
# city               San Francisco
# category               Furniture
# product_id       FUR-TA-10003715
# sales                    502.488
# profit                  -87.9354
# Name: 1, dtype: object

# %%
df.loc[1,'customer_name']
# Out:
# 'Ed Braxton'

# %%
df.set_index('customer_name')
# Out:
#                          order_id  order_date           city         category  \
# customer_name
# Dennis Kane        CA-2018-100006  2018-09-07  New York City       Technology
# Ed Braxton         CA-2018-100090  2018-07-08  San Francisco        Furniture
# Neil Französisch   CA-2018-100293  2018-03-14   Jacksonville  Office Supplies
# Jasper Cacioppo    CA-2018-100328  2018-01-28  New York City  Office Supplies
# Jim Mitchum        CA-2018-100363  2018-04-08       Glendale  Office Supplies
# ...                           ...         ...            ...              ...
# Jack O'Briant      US-2021-168802  2021-11-03        Seattle  Office Supplies
# Lena Hernandez     US-2021-169320  2021-07-23        Elkhart  Office Supplies
# Allen Armold       US-2021-169488  2021-09-07     Providence  Office Supplies
# Matthew Grinstein  US-2021-169502  2021-08-28      Milwaukee  Office Supplies
# Rob Lucas          US-2021-169551  2021-07-07   Philadelphia        Furniture
#
# ...

# %%
# reset index

df.reset_index()
# Out:
#       index        order_id  order_date      customer_name           city  \
# 0         0  CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1         1  CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2         2  CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3         3  CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4         4  CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...     ...             ...         ...                ...            ...
# 5004   5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005   5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006   5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007   5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008   5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# ...

# %%
# iloc

df.iloc[1:5,1:3]
# Out:
#    order_date     customer_name
# 1  2018-07-08        Ed Braxton
# 2  2018-03-14  Neil Französisch
# 3  2018-01-28   Jasper Cacioppo
# 4  2018-04-08       Jim Mitchum

# %%
# loc

df.loc[1:5,['sales']]
# Out:
#      sales
# 1  502.488
# 2   91.056
# 3    3.928
# 4    2.368
# 5   14.620

# %%
# sort thr index

df.sort_index()
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
# sort on name

df_1 = df.set_index(['customer_name'])

# %%
df_1.sort_index()
# Out:
#                           order_id  order_date           city  \
# customer_name
# Aaron Bergman       CA-2020-140935  2020-11-10  Oklahoma City
# Aaron Bergman       CA-2018-156587  2018-03-07        Seattle
# Aaron Bergman       CA-2018-152905  2018-02-18      Arlington
# Aaron Hawkins       CA-2018-113768  2018-05-13    Los Angeles
# Aaron Hawkins       CA-2019-130113  2019-12-27  San Francisco
# ...                            ...         ...            ...
# Zuschuss Donatelli  CA-2018-143336  2018-08-27  San Francisco
# Zuschuss Donatelli  US-2020-147991  2020-05-05    Chattanooga
# Zuschuss Donatelli  CA-2021-141481  2021-06-11    Los Angeles
# Zuschuss Donatelli  CA-2020-152471  2020-07-08   Jacksonville
# Zuschuss Donatelli  CA-2020-167682  2020-04-03       Richmond
#
#                            category       product_id    sales   profit
# customer_name
# Aaron Bergman             Furniture  FUR-BO-10003966  341.960  54.7136
# ...

# %%
# see the category 

df['category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
# category count

df['category'].value_counts()
# Out:
# category
# Office Supplies    2773
# Furniture          1764
# Technology          472
# Name: count, dtype: int64

# %%
# count on multiple columns

df[['category','city']].value_counts()
# Out:
# category         city
# Office Supplies  New York City        257
#                  Los Angeles          210
# Furniture        New York City        157
# Office Supplies  Philadelphia         152
#                  San Francisco        149
# Furniture        Los Angeles          138
# Office Supplies  Seattle              109
#                  Chicago               99
#                  Houston               98
# Furniture        San Francisco         91
#                  Philadelphia          89
#                  Seattle               84
#                  Houston               68
# Office Supplies  Columbus              61
# Furniture        Chicago               56
# Office Supplies  Dallas                47
#                  Springfield           45
#                  San Diego             43
# Furniture        Columbus              40
# Technology       Los Angeles           36
#                  New York City         36
# Furniture        San Diego             36
# ...
